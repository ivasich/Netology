# %% [markdown]
# Задание 1**
# Напишите функцию, которая классифицирует фильмы из материалов занятия по следующим правилам:
#
# оценка 2 и меньше - низкий рейтинг
# оценка 4 и меньше - средний рейтинг
# оценка 4.5 и 5 - высокий рейтинг
# Результат классификации запишите в столбец class

# %%
import pandas as pd

# %%
data = pd.read_csv("ratings.csv")

# %%
def set_rating_class(rating):
    if rating <= 2:
        return "Низкий"
    
    if rating > 4:
        return "Высокий"
    
    return "Середнячок"

# %%
data["class"] = data["rating"].apply(set_rating_class)
data.head(30)
# Out:
#     userId  movieId  rating   timestamp       class
# 0        1       31     2.5  1260759144  Середнячок
# 1        1     1029     3.0  1260759179  Середнячок
# 2        1     1061     3.0  1260759182  Середнячок
# 3        1     1129     2.0  1260759185      Низкий
# 4        1     1172     4.0  1260759205  Середнячок
# 5        1     1263     2.0  1260759151      Низкий
# 6        1     1287     2.0  1260759187      Низкий
# 7        1     1293     2.0  1260759148      Низкий
# 8        1     1339     3.5  1260759125  Середнячок
# 9        1     1343     2.0  1260759131      Низкий
# 10       1     1371     2.5  1260759135  Середнячок
# 11       1     1405     1.0  1260759203      Низкий
# 12       1     1953     4.0  1260759191  Середнячок
# 13       1     2105     4.0  1260759139  Середнячок
# 14       1     2150     3.0  1260759194  Середнячок
# 15       1     2193     2.0  1260759198      Низкий
# 16       1     2294     2.0  1260759108      Низкий
# ...

# %% [markdown]
# Задание 2
# Используем файл keywords.csv.
#
# Необходимо написать гео-классификатор, который каждой строке сможет выставить географическую принадлежность определенному региону. Т. е. если поисковый запрос содержит название города региона, то в столбце ‘region’ пишется название этого региона. Если поисковый запрос не содержит названия города, то ставим ‘undefined’.
#
# Правила распределения по регионам Центр, Северо-Запад и Дальний Восток:
#
# geo_data = {
#
# 'Центр': ['москва', 'тула', 'ярославль'],
#
# 'Северо-Запад': ['петербург', 'псков', 'мурманск'],
#
# 'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']
# }
# Результат классификации запишите в отдельный столбец region.

# %%
dataf = pd.read_csv("keywords.csv")
geo_data = {
'Центр': ['москва', 'тула', 'ярославль', 'оренбург'],
'Северо-Запад': ['петербург', 'псков', 'мурманск'],
'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск'],
'Юго-Запад': ["ялта", "старый оскол" ]
}

# %%
def region(kw, geo):
    for k, v in geo.items():
        if any([town in kw for town in v]):
            return k
    return "undefined"

# %%
dataf["region"] = dataf["keyword"].apply(region, geo=geo_data)

# %%
dataf[ dataf["region"] != "undefined" ]
# Out:
#                                                  keyword   shows  \
# 127                                         авито москва  979292
# 370                             авито ру санкт петербург  425134
# 564                            погода в санкт петербурге  292489
# 756                                       авито оренбург  233857
# 849                                      авито ярославль  209581
# 1063                                 фарпост владивосток  176951
# 1236                                банк санкт петербург  174375
# 1259                                              москва  153050
# 1346                                     санкт петербург  144232
# 1396                                     гисметео москва  140279
# 1482                                    госуслуги москва  133061
# 1579                                          авито тула  126168
# 1625                                  погода в оренбурге  115576
# ...
